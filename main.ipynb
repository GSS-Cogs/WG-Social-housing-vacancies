# %%
from gssutils import *
from requests import Session
from cachecontrol import CacheControl
from cachecontrol.caches.file_cache import FileCache
from cachecontrol.heuristics import ExpiresAfter

scraper = Scraper('https://statswales.gov.wales/Catalogue/Housing/Social-Housing-Vacancies/'
                  'vacancies-by-area-availability-duration',
                  session=CacheControl(Session(),
                                       cache=FileCache('.cache'),
                                       heuristic=ExpiresAfter(days=7)))
scraper
# Out:
# WARNING:http://open.statswales.gov.wales/en-gb/discover/metadata?$filter=Dataset eq 'hous1401' does not look like a valid URI, trying to serialize this will break.
# WARNING:http://open.statswales.gov.wales/en-gb/discover/datasetdimensions?$filter=Dataset eq 'hous1401' does not look like a valid URI, trying to serialize this will break.
# WARNING:http://open.statswales.gov.wales/en-gb/discover/datasetdimensionitems?$filter=Dataset eq 'hous1401' does not look like a valid URI, trying to serialize this will break.
# ## Social housing vacancies
#
# The information presented here covers the number of vacancies within housing stock held by Local Authorities and Registered Social Landlords. The information is collected via new annual returns from Welsh social landlords in order to monitor trends over time in the proportion of housing stock which is vacant. Vacant dwellings includes:1.)Dwellings undergoing or awaiting major capital works repair, conversion or improvement;2.)Vacant dwellings that have formal approval for sale or demolition only if they are still part of HRA (Housing Revenue Account) dwellings;3.)All vacant dwellings to be sold whether awaiting sale or undergoing repair prior to being sold; 4.)Vacant dwellings subject to demolition or closing orders or acquired for demolition under Part VI or IX of the Housing Act 1985. The information presented here excludes vacant dwellings where an offer of tenancy has been accepted even if no rent is being paid at the end of the financial year.
#
# ### Distributions
#
# 1. Dataset ([application/json](http://open.statswales.gov.wales/dataset/hous1401))
# 1. Dimensions ([application/json](http://open.statswales.gov.wales/en-gb/discover/datasetdimensions?$filter=Dataset eq 'hous1401'))
# 1. Metadata ([application/json](http://open.statswales.gov.wales/en-gb/discover/metadata?$filter=Dataset eq 'hous1401'))
# 1. Items ([application/json](http://open.statswales.gov.wales/en-gb/discover/datasetdimensionitems?$filter=Dataset eq 'hous1401'))

# %%
if len(scraper.distributions) == 0:
    from gssutils.metadata import Distribution
    dist = Distribution(scraper)
    dist.title = 'Dataset'
    dist.downloadURL = 'http://open.statswales.gov.wales/dataset/hous1401'
    dist.mediaType = 'application/json'
    scraper.distributions.append(dist)
table = scraper.distribution(title='Dataset').as_pandas()

# %%
table = table[['Area_AltCode1','Availability_ItemName_ENG','Data','Duration_ItemName_ENG','Provider_ItemName_ENG','Vacancy_ItemName_ENG','Year_Code'
]]

# %%
table.rename(columns={'Area_AltCode1': 'Geography','Availability_ItemName_ENG':'Available to let','Data': 'Value','Duration_ItemName_ENG': 'Vacancy Duration','Provider_ItemName_ENG':'Provider','Vacancy_ItemName_ENG': 'Vacancy Type','Year_Code':'Year'}, inplace=True)

# %%
table['Period'] = table['Year'].map(
    lambda x: f'gregorian-interval/{str(x)[:4]}-03-31T00:00:00/P1Y')

# %%
table['Measure Type'] = 'Count' 
table['Unit'] = 'vacancies'

# %%
table = table[['Geography','Period','Available to let','Value','Vacancy Duration','Provider',
               'Vacancy Type','Measure Type','Unit']]

# %%
out = Path('out')
out.mkdir(exist_ok=True, parents=True)

table.to_csv(out / 'observations.csv', index = False)

# %%
schema = CSVWSchema('https://ons-opendata.github.io/ref_housing/')
schema.create(out / 'observations.csv', out / 'observations.csv-schema.json')
# Out:
# "Available to let" not defined
# "Vacancy Duration" not defined
# "Provider" not defined
# "Vacancy Type" not defined

# %%
from datetime import datetime
scraper.dataset.family = 'housing'
scraper.dataset.theme = THEME['housing-planning-local-services']
scraper.dataset.modified = datetime.now()
scraper.dataset.creator = scraper.dataset.publisher
with open(out / 'dataset.trig', 'wb') as metadata:
    metadata.write(scraper.generate_trig())

# %%
table
# Out:
#         Geography                                      Period  \
# 0       W06000016  gregorian-interval/2005-03-31T00:00:00/P1Y
# 1       W06000021  gregorian-interval/2001-03-31T00:00:00/P1Y
# 2       W06000022  gregorian-interval/2005-03-31T00:00:00/P1Y
# 3       W06000004  gregorian-interval/2005-03-31T00:00:00/P1Y
# 4       W06000013  gregorian-interval/2007-03-31T00:00:00/P1Y
# 5       W06000013  gregorian-interval/2007-03-31T00:00:00/P1Y
# 6       W06000013  gregorian-interval/2007-03-31T00:00:00/P1Y
# 7       W06000013  gregorian-interval/2007-03-31T00:00:00/P1Y
# 8       W06000013  gregorian-interval/2006-03-31T00:00:00/P1Y
# 9       W06000013  gregorian-interval/2006-03-31T00:00:00/P1Y
# 10      W06000013  gregorian-interval/2006-03-31T00:00:00/P1Y
# 11      W06000013  gregorian-interval/2006-03-31T00:00:00/P1Y
# 12      W06000013  gregorian-interval/2005-03-31T00:00:00/P1Y
# 13      W06000013  gregorian-interval/2005-03-31T00:00:00/P1Y
# 14      W06000013  gregorian-interval/2005-03-31T00:00:00/P1Y
# 15      W06000013  gregorian-interval/2005-03-31T00:00:00/P1Y
# 16      W06000016  gregorian-interval/2007-03-31T00:00:00/P1Y
# 17      W06000016  gregorian-interval/2007-03-31T00:00:00/P1Y
# 18      W06000016  gregorian-interval/2007-03-31T00:00:00/P1Y
# 19      W06000016  gregorian-interval/2007-03-31T00:00:00/P1Y
# 20      W06000019  gregorian-interval/2005-03-31T00:00:00/P1Y
# 21      W06000020  gregorian-interval/2007-03-31T00:00:00/P1Y
# 22      W06000020  gregorian-interval/2007-03-31T00:00:00/P1Y
# 23      W06000020  gregorian-interval/2007-03-31T00:00:00/P1Y
# 24      W06000020  gregorian-interval/2007-03-31T00:00:00/P1Y
# 25      W06000021  gregorian-interval/2007-03-31T00:00:00/P1Y
# 26      W06000021  gregorian-interval/2007-03-31T00:00:00/P1Y
# 27      W06000021  gregorian-interval/2007-03-31T00:00:00/P1Y
# 28      W06000021  gregorian-interval/2007-03-31T00:00:00/P1Y
# 29      W06000001  gregorian-interval/2014-03-31T00:00:00/P1Y
# ...           ...                                         ...
# 271875  W06000013  gregorian-interval/2017-03-31T00:00:00/P1Y
# 271876  W06000019  gregorian-interval/2011-03-31T00:00:00/P1Y
# 271877  W06000019  gregorian-interval/2011-03-31T00:00:00/P1Y
# 271878  W06000019  gregorian-interval/2011-03-31T00:00:00/P1Y
# 23          Available for letting   -999  Vacant for less than 6 months
# 24      Not available for letting   -999  Vacant for less than 6 months
# 25      Not available for letting   -999    Vacant for 6 months or more
# 26      Not available for letting   -999  Vacant for less than 6 months
# 27          Available for letting   -999  Vacant for less than 6 months
# 28          Available for letting   -999    Vacant for 6 months or more
# 29                          Total      0  Vacant for less than 6 months
# ...                           ...    ...                            ...
# 271875                      Total     99                          Total
# 271876                      Total     99    Vacant for 6 months or more
# 271877                      Total     99                          Total
# 271878                      Total     99    Vacant for 6 months or more
# 271879  Not available for letting     99    Vacant for 6 months or more
# 271880  Not available for letting     99    Vacant for 6 months or more
# 271881      Available for letting     99  Vacant for less than 6 months
# 271882      Available for letting     99                          Total
# 271883      Available for letting     99                          Total
# 271884                      Total     99                          Total
# 271885                      Total     99                          Total
# 271886                      Total     99  Vacant for less than 6 months
# 271887                      Total     99                          Total
# 271888                      Total     99                          Total
# 271889                      Total     99  Vacant for less than 6 months
# 271890                      Total     99  Vacant for less than 6 months
# 271891                      Total     99  Vacant for less than 6 months
# 271892                      Total     99  Vacant for less than 6 months
# 271893      Available for letting     99                          Total
# 271894      Available for letting     99                          Total
# 271895                      Total     99                          Total
# 271896                      Total     99                          Total
# 271897  Not available for letting     99    Vacant for 6 months or more
# 271898  Not available for letting     99    Vacant for 6 months or more
# 271899                      Total    991                          Total
# 271900      Available for letting    992                          Total
# 271901  Not available for letting    994  Vacant for less than 6 months
# 271902  Not available for letting    994  Vacant for less than 6 months
# 271903  Not available for letting    996  Vacant for less than 6 months
# 271904  Not available for letting    998                          Total
#
#                                  Provider  \
# 0                       Rhondda Cynon Taf
# 1                           Monmouthshire
# 2                                 Newport
# 3                            Denbighshire
# 4                                Bridgend
# 5                                Bridgend
# 6                                Bridgend
# 7                                Bridgend
# 8                                Bridgend
# 9                                Bridgend
# 10                               Bridgend
# 11                               Bridgend
# 12                               Bridgend
# 13                               Bridgend
# 14                               Bridgend
# 15                               Bridgend
# 16                      Rhondda Cynon Taf
# 17                      Rhondda Cynon Taf
# 18                      Rhondda Cynon Taf
# 19                      Rhondda Cynon Taf
# 20                          Blaenau Gwent
# 21                                Torfaen
# 22                                Torfaen
# 23                                Torfaen
# 24                                Torfaen
# 25                          Monmouthshire
# 26                          Monmouthshire
# 27                          Monmouthshire
# 28                          Monmouthshire
# 29                       Isle of Anglesey
# ...                                   ...
# 271875                              Wales
# 271876                              Wales
# 271877                              Wales
# 271878                              Wales
# 271879                              Wales
# 271880                              Wales
# 271881                              Wales
# 271882                              Wales
# 271883                              Wales
# 271884               Gwalia Housing Group
# 271885               Gwalia Housing Group
# 271886               Gwalia Housing Group
# 271887             Wales and West Housing
# 271888             Wales and West Housing
# 271889                          Trivallis
# 271890                          Trivallis
# 271891                          Trivallis
# 271892                          Trivallis
# 271893                 Newport City Homes
# 271894                 Newport City Homes
# 271895                 Newport City Homes
# 271896                 Newport City Homes
# 271897                          NPT Homes
# 271898                          NPT Homes
# 271899                              Wales
# 271900  Total Registered Social Landlords
# 271901                              Wales
# 271902                              Wales
# 271903                              Wales
# 271904  Total Registered Social Landlords
#
#                                              Vacancy Type Measure Type  \
# 0                                                   Total        Count
# 1                                                   Total        Count
# 2                                                   Total        Count
# 3                                                   Total        Count
# 4                                                   Total        Count
# 5                                                   Total        Count
# 6                                                   Total        Count
# 7                                                   Total        Count
# 8                                                   Total        Count
# 9                                                   Total        Count
# 10                                                  Total        Count
# 11                                                  Total        Count
# 12                                                  Total        Count
# 13                                                  Total        Count
# 14                                                  Total        Count
# 15                                                  Total        Count
# 16                                                  Total        Count
# 17                                                  Total        Count
# 18                                                  Total        Count
# 19                                                  Total        Count
# 20                                                  Total        Count
# 21                                                  Total        Count
# 22                                                  Total        Count
# 23                                                  Total        Count
# 24                                                  Total        Count
# 25                                                  Total        Count
# 26                                                  Total        Count
# 27                                                  Total        Count
# 28                                                  Total        Count
# 29      Self-contained other supported (2011-12 onward...        Count
# ...                                                   ...          ...
# 271875                                 All self-contained        Count
# 271876                                 All self-contained        Count
# 271877    Self-contained sheltered (2011-12 onwards only)        Count
# 271878                                              Total        Count
# 271879  Self-contained sheltered and other supported (...        Count
# 271880    Self-contained sheltered (2011-12 onwards only)        Count
# 271881                                 All self-contained        Count
# 271882                                              Total        Count
# 271883                       Self-contained general needs        Count
# 271884                                              Total        Count
# 271885                                              Total        Count
# 271886                                              Total        Count
# 271887                                              Total        Count
# 271888                                 All self-contained        Count
# 271889                                 All self-contained        Count
# 271890                                              Total        Count
# 271891                                              Total        Count
# 271892                                 All self-contained        Count
# 271893                                              Total        Count
# 271894                                              Total        Count
# 271895                       Self-contained general needs        Count
# 271896                       Self-contained general needs        Count
# 271897                                 All self-contained        Count
# 271898                                 All self-contained        Count
# 271899                                              Total        Count
# 271900                       Self-contained general needs        Count
# 271901                       Self-contained general needs        Count
# 271902                                              Total        Count
# 271903                       Self-contained general needs        Count
# 271904                                              Total        Count
#
#              Unit
# 0       vacancies
# 1       vacancies
# 2       vacancies
# 3       vacancies
# 4       vacancies
# 5       vacancies
# 6       vacancies
# 7       vacancies
# 8       vacancies
# 9       vacancies
# 10      vacancies
# 11      vacancies
# 12      vacancies
# 13      vacancies
# 14      vacancies
# 15      vacancies
# 16      vacancies
# 17      vacancies
# 18      vacancies
# 19      vacancies
# 20      vacancies
# 21      vacancies
# 22      vacancies
# 23      vacancies
# 24      vacancies
# 25      vacancies
# 26      vacancies
# 27      vacancies
# 28      vacancies
# 29      vacancies
# ...           ...
# 271875  vacancies
# 271876  vacancies
# 271877  vacancies
# 271878  vacancies
# 271879  vacancies
# 271880  vacancies
# 271881  vacancies
# 271882  vacancies
# 271883  vacancies
# 271884  vacancies
# 271885  vacancies
# 271886  vacancies
# 271887  vacancies
# 271888  vacancies
# 271889  vacancies
# 271890  vacancies
# 271891  vacancies
# 271892  vacancies
# 271893  vacancies
# 271894  vacancies
# 271895  vacancies
# 271896  vacancies
# 271897  vacancies
# 271898  vacancies
# 271899  vacancies
# 271900  vacancies
# 271901  vacancies
# 271902  vacancies
# 271903  vacancies
# 271904  vacancies
#
# [271905 rows x 9 columns]
