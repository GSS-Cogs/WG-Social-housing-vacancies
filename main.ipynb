# %%
from gssutils import *
from requests import Session
from cachecontrol import CacheControl
from cachecontrol.caches.file_cache import FileCache
from cachecontrol.heuristics import ExpiresAfter

scraper = Scraper('https://statswales.gov.wales/Catalogue/Housing/Social-Housing-Vacancies/'
                  'vacancies-by-area-availability-duration',
                  session=CacheControl(Session(),
                                       cache=FileCache('.cache'),
                                       heuristic=ExpiresAfter(days=7)))
scraper
# Out:
# WARNING:http://open.statswales.gov.wales/en-gb/discover/metadata?$filter=Dataset eq 'hous1401' does not look like a valid URI, trying to serialize this will break.
# WARNING:http://open.statswales.gov.wales/en-gb/discover/datasetdimensions?$filter=Dataset eq 'hous1401' does not look like a valid URI, trying to serialize this will break.
# WARNING:http://open.statswales.gov.wales/en-gb/discover/datasetdimensionitems?$filter=Dataset eq 'hous1401' does not look like a valid URI, trying to serialize this will break.
# ## Social housing vacancies
#
# The information presented here covers the number of vacancies within housing stock held by Local Authorities and Registered Social Landlords. The information is collected via new annual returns from Welsh social landlords in order to monitor trends over time in the proportion of housing stock which is vacant. Vacant dwellings includes:1.)Dwellings undergoing or awaiting major capital works repair, conversion or improvement;2.)Vacant dwellings that have formal approval for sale or demolition only if they are still part of HRA (Housing Revenue Account) dwellings;3.)All vacant dwellings to be sold whether awaiting sale or undergoing repair prior to being sold; 4.)Vacant dwellings subject to demolition or closing orders or acquired for demolition under Part VI or IX of the Housing Act 1985. The information presented here excludes vacant dwellings where an offer of tenancy has been accepted even if no rent is being paid at the end of the financial year.
#
# ### Distributions
#
# 1. Metadata ([application/json](http://open.statswales.gov.wales/en-gb/discover/metadata?$filter=Dataset eq 'hous1401'))
# 1. Dimensions ([application/json](http://open.statswales.gov.wales/en-gb/discover/datasetdimensions?$filter=Dataset eq 'hous1401'))
# 1. Items ([application/json](http://open.statswales.gov.wales/en-gb/discover/datasetdimensionitems?$filter=Dataset eq 'hous1401'))
# 1. Dataset ([application/json](http://open.statswales.gov.wales/dataset/hous1401))

# %%
if len(scraper.distributions) == 0:
    from gssutils.metadata import Distribution
    dist = Distribution(scraper)
    dist.title = 'Dataset'
    dist.downloadURL = 'http://open.statswales.gov.wales/dataset/hous1401'
    dist.mediaType = 'application/json'
    scraper.distributions.append(dist)
table = scraper.distribution(title='Dataset').as_pandas()
table
# Out:
# WARNING:Cache entry deserialization failed, entry ignored
# WARNING:Cache entry deserialization failed, entry ignored
# WARNING:Cache entry deserialization failed, entry ignored
# WARNING:Cache entry deserialization failed, entry ignored
# WARNING:Cache entry deserialization failed, entry ignored
#        Area_AltCode1  Area_Code  Area_Hierarchy  Area_ItemName_ENG  \
# 0          W06000016        540             600  Rhondda Cynon Taf
# 1          W06000021        548             600      Monmouthshire
# 2          W06000022        550             600            Newport
# 3          W06000004        518             600       Denbighshire
# 4          W06000013        536             600           Bridgend
# 5          W06000013        536             600           Bridgend
# 6          W06000013        536             600           Bridgend
# 7          W06000013        536             600           Bridgend
# 8          W06000013        536             600           Bridgend
# 9          W06000013        536             600           Bridgend
# 10         W06000013        536             600           Bridgend
# 11         W06000013        536             600           Bridgend
# 12         W06000013        536             600           Bridgend
# 13         W06000013        536             600           Bridgend
# 14         W06000013        536             600           Bridgend
# 15         W06000013        536             600           Bridgend
# 16         W06000016        540             600  Rhondda Cynon Taf
# 17         W06000016        540             600  Rhondda Cynon Taf
# 18         W06000016        540             600  Rhondda Cynon Taf
# 19         W06000016        540             600  Rhondda Cynon Taf
# 20         W06000019        545             600      Blaenau Gwent
# 21         W06000020        546             600            Torfaen
# 22         W06000020        546             600            Torfaen
# 23         W06000020        546             600            Torfaen
# 24         W06000020        546             600            Torfaen
# 25         W06000021        548             600      Monmouthshire
# 26         W06000021        548             600      Monmouthshire
# 27         W06000021        548             600      Monmouthshire
# 28         W06000021        548             600      Monmouthshire
# 29         W06000001        512             600   Isle of Anglesey
# ...              ...        ...             ...                ...
# 271875     W06000013        536             600           Bridgend
# 271876     W06000019        545             600      Blaenau Gwent
# 271877     W06000019        545             600      Blaenau Gwent
# 271878     W06000019        545             600      Blaenau Gwent
# 271879     W06000016        540             600  Rhondda Cynon Taf
# 271880     W06000016        540             600  Rhondda Cynon Taf
# 271881     W06000012        534             600  Neath Port Talbot
# 271882     W06000014        538             600  Vale of Glamorgan
# 271883     W06000012        534             600  Neath Port Talbot
# 271884     W92000004        600               0              Wales
# 271885     W06000011        532             600            Swansea
# 271886     W92000004        600               0              Wales
# 271887     W92000004        600               0              Wales
# 271888     W92000004        600               0              Wales
# 271889     W92000004        600               0              Wales
# 271890     W92000004        600               0              Wales
# 271891     W06000016        540             600  Rhondda Cynon Taf
# 271892     W06000016        540             600  Rhondda Cynon Taf
# 271893     W92000004        600               0              Wales
# 271894     W06000022        550             600            Newport
# 271895     W92000004        600               0              Wales
# 271896     W06000022        550             600            Newport
# 271897     W92000004        600               0              Wales
# 271898     W06000012        534             600  Neath Port Talbot
# 271899     W06000016        540             600  Rhondda Cynon Taf
# 271900     W92000004        600               0              Wales
# 271901     W92000004        600               0              Wales
# 271902     W92000004        600               0              Wales
# 271903     W92000004        600               0              Wales
# 271904     W92000004        600               0              Wales
#
#         Area_SortOrder  Availability_Code  Availability_Hierarchy  \
# 0                   17                  1                       3
# 1                   22                  1                       3
# 2                   23                  2                       3
# 3                    5                  1                       3
# 4                   14                  2                       3
# 5                   14                  1                       3
# 6                   14                  2                       3
# 7                   14                  1                       3
# 8                   14                  1                       3
# 9                   14                  2                       3
# 10                  14                  2                       3
# 11                  14                  1                       3
# 12                  14                  2                       3
# 13                  14                  1                       3
# 14                  14                  2                       3
# 15                  14                  1                       3
# 16                  17                  2                       3
# 17                  17                  1                       3
# 18                  17                  2                       3
# 19                  17                  1                       3
# 20                  20                  1                       3
# 21                  21                  1                       3
# 22                  21                  2                       3
# 23                  21                  1                       3
# 24                  21                  2                       3
# 25                  22                  2                       3
# 26                  22                  2                       3
# 27                  22                  1                       3
# 28                  22                  1                       3
# 29                   2                  3                       0
# ...                ...                ...                     ...
# 271875              14                  3                       0
# 271876              20                  3                       0
# 271877              20                  3                       0
# 271878              20                  3                       0
# 271879              17                  2                       3
# 271880              17                  2                       3
# 271881              13                  1                       3
# 271882              15                  1                       3
# 271883              13                  1                       3
# 271884               1                  3                       0
# 271885              12                  3                       0
# 271886               1                  3                       0
# 271887               1                  3                       0
# 271888               1                  3                       0
# 271889               1                  3                       0
# 271890               1                  3                       0
# 271891              17                  3                       0
# 271892              17                  3                       0
# 271893               1                  1                       3
# 271894              23                  1                       3
# 271895               1                  3                       0
# 271896              23                  3                       0
# 271897               1                  2                       3
# 271898              13                  2                       3
# 271899              17                  3                       0
# 271900               1                  1                       3
# 271901               1                  2                       3
# 271902               1                  2                       3
# 271903               1                  2                       3
# 271904               1                  2                       3
#
#         Availability_ItemName_ENG  Availability_SortOrder  Data  \
# 0           Available for letting                       2    -1
# 1           Available for letting                       2    -2
# 2       Not available for letting                       3    -8
# 3           Available for letting                       2  -999
# 4       Not available for letting                       3  -999
# 5           Available for letting                       2  -999
# 6       Not available for letting                       3  -999
# 7           Available for letting                       2  -999
# 8           Available for letting                       2  -999
# 9       Not available for letting                       3  -999
# 10      Not available for letting                       3  -999
# 11          Available for letting                       2  -999
# 12      Not available for letting                       3  -999
# 13          Available for letting                       2  -999
# 14      Not available for letting                       3  -999
# 15          Available for letting                       2  -999
# 16      Not available for letting                       3  -999
# 17          Available for letting                       2  -999
# 18      Not available for letting                       3  -999
# 19          Available for letting                       2  -999
# 20          Available for letting                       2  -999
# 21          Available for letting                       2  -999
# 22      Not available for letting                       3  -999
# 23          Available for letting                       2  -999
# 24      Not available for letting                       3  -999
# 25      Not available for letting                       3  -999
# 26      Not available for letting                       3  -999
# 27          Available for letting                       2  -999
# 28          Available for letting                       2  -999
# 29                          Total                       1     0
# ...                           ...                     ...   ...
# 271875                      Total                       1    99
# 271876                      Total                       1    99
# 271877                      Total                       1    99
# 271878                      Total                       1    99
# 271879  Not available for letting                       3    99
# 271880  Not available for letting                       3    99
# 271881      Available for letting                       2    99
# 271882      Available for letting                       2    99
# 271883      Available for letting                       2    99
# 271884                      Total                       1    99
# 271885                      Total                       1    99
# 271886                      Total                       1    99
# 271887                      Total                       1    99
# 271888                      Total                       1    99
# 271889                      Total                       1    99
# 271890                      Total                       1    99
# 271891                      Total                       1    99
# 271892                      Total                       1    99
# 271893      Available for letting                       2    99
# 271894      Available for letting                       2    99
# 271895                      Total                       1    99
# 271896                      Total                       1    99
# 271897  Not available for letting                       3    99
# 271898  Not available for letting                       3    99
# 271899                      Total                       1   991
# 271900      Available for letting                       2   992
# 271901  Not available for letting                       3   994
# 271902  Not available for letting                       3   994
# 271903  Not available for letting                       3   996
# 271904  Not available for letting                       3   998
#
#             ...        RowKey  Vacancy_Code Vacancy_Hierarchy  \
# 0           ...         15882           6.0                 0
# 1           ...         18539           6.0                 0
# 2           ...         18714           6.0                 0
# 3           ...          2414           6.0                 0
# 4           ...         13936           6.0                 0
# 5           ...         13937           6.0                 0
# 6           ...         13939           6.0                 0
# 7           ...         13940           6.0                 0
# 8           ...         13941           6.0                 0
# 9           ...         13942           6.0                 0
# 10          ...         13945           6.0                 0
# 11          ...         13958           6.0                 0
# 12          ...         13959           6.0                 0
# 13          ...         13968           6.0                 0
# 14          ...         13969           6.0                 0
# 15          ...         13971           6.0                 0
# 16          ...         15840           6.0                 0
# 17          ...         15846           6.0                 0
# 18          ...         15868           6.0                 0
# 19          ...         15876           6.0                 0
# 20          ...         17825           6.0                 0
# 21          ...         18252           6.0                 0
# 22          ...         18257           6.0                 0
# 23          ...         18274           6.0                 0
# 24          ...         18275           6.0                 0
# 25          ...         18471           6.0                 0
# 26          ...         18472           6.0                 0
# 27          ...         18474           6.0                 0
# 28          ...         18477           6.0                 0
# 29          ...             0           2.2                 5
# ...         ...           ...           ...               ...
# 271875      ...         62174           5.0                 6
# 271876      ...         63045           5.0                 6
# 271877      ...         63120           2.1                 5
# 271878      ...         63191           6.0                 0
# 271879      ...         63281           2.0                 5
# 271880      ...         63289           2.1                 5
# 271881      ...         64365           5.0                 6
# 271882      ...         64411           6.0                 0
# 271883      ...         64483           1.0                 5
# 271884      ...        141319           6.0                 0
# 271885      ...        143672           6.0                 0
# 271886      ...        146236           6.0                 0
# 271887      ...        214388           6.0                 0
# 271888      ...        214413           5.0                 6
# 271889      ...        238113           5.0                 6
# 271890      ...        238115           6.0                 0
# 271891      ...        239242           6.0                 0
# 271892      ...        239251           5.0                 6
# 271893      ...        247672           6.0                 0
# 271894      ...        248232           6.0                 0
# 271895      ...        248415           1.0                 5
# 271896      ...        248799           1.0                 5
# 271897      ...        254789           5.0                 6
# 271898      ...        255338           5.0                 6
# 271899      ...         55348           6.0                 0
# 271900      ...         33096           1.0                 5
# 271901      ...         48123           1.0                 5
# 271902      ...         60028           6.0                 0
# 271903      ...         48236           1.0                 5
# 271904      ...         21117           6.0                 0
#
#                                      Vacancy_ItemName_ENG  \
# 0                                                   Total
# 1                                                   Total
# 2                                                   Total
# 3                                                   Total
# 4                                                   Total
# 5                                                   Total
# 6                                                   Total
# 7                                                   Total
# 8                                                   Total
# 9                                                   Total
# 10                                                  Total
# 11                                                  Total
# 12                                                  Total
# 13                                                  Total
# 14                                                  Total
# 15                                                  Total
# 16                                                  Total
# 17                                                  Total
# 18                                                  Total
# 19                                                  Total
# 20                                                  Total
# 21                                                  Total
# 22                                                  Total
# 23                                                  Total
# 24                                                  Total
# 25                                                  Total
# 26                                                  Total
# 27                                                  Total
# 28                                                  Total
# 29      Self-contained other supported (2011-12 onward...
# ...                                                   ...
# 271875                                 All self-contained
# 271876                                 All self-contained
# 271877    Self-contained sheltered (2011-12 onwards only)
# 271878                                              Total
# 271879  Self-contained sheltered and other supported (...
# 271880    Self-contained sheltered (2011-12 onwards only)
# 271881                                 All self-contained
# 271882                                              Total
# 271883                       Self-contained general needs
# 271884                                              Total
# 271885                                              Total
# 271886                                              Total
# 271887                                              Total
# 271888                                 All self-contained
# 271889                                 All self-contained
# 271890                                              Total
# 271891                                              Total
# 271892                                 All self-contained
# 271893                                              Total
# 271894                                              Total
# 271895                       Self-contained general needs
# 271896                       Self-contained general needs
# 271897                                 All self-contained
# 271898                                 All self-contained
# 271899                                              Total
# 271900                       Self-contained general needs
# 271901                       Self-contained general needs
# 271902                                              Total
# 271903                       Self-contained general needs
# 271904                                              Total
#
#         Vacancy_ItemNotes_ENG  Vacancy_SortOrder  Year_Code  \
# 0                                              1     200506
# 1                                              1     200102
# 2                                              1     200506
# 3                                              1     200506
# 4                                              1     200708
# 5                                              1     200708
# 6                                              1     200708
# 7                                              1     200708
# 8                                              1     200607
# 9                                              1     200607
# 10                                             1     200607
# 11                                             1     200607
# 12                                             1     200506
# 13                                             1     200506
# 14                                             1     200506
# 15                                             1     200506
# 16                                             1     200708
# 17                                             1     200708
# 18                                             1     200708
# 19                                             1     200708
# 20                                             1     200506
# 21                                             1     200708
# 22                                             1     200708
# 23                                             1     200708
# 24                                             1     200708
# 25                                             1     200708
# 26                                             1     200708
# 27                                             1     200708
# 28                                             1     200708
# 29       2011-12 onwards only                  6     201415
# ...                       ...                ...        ...
# 271875                                         3     201718
# 271876                                         3     201112
# 271877   2011-12 onwards only                  5     201112
# 271878                                         1     201112
# 271879                                         7     201112
# 271880   2011-12 onwards only                  5     201112
# 271881                                         3     200910
# 271882                                         1     200910
# 271883                                         4     200910
# 271884                                         1     201617
# 271885                                         1     200102
# 271886                                         1     201516
# 271887                                         1     201415
# 271888                                         3     201415
# 271889                                         3     201112
# 271890                                         1     201112
# 271891                                         1     201112
# 271892                                         3     201112
# 271893                                         1     201314
# 271894                                         1     201314
# 271895                                         4     201516
# 271896                                         4     201516
# 271897                                         3     201617
# 271898                                         3     201617
# 271899                                         1     200304
# 271900                                         4     201516
# 271901                                         4     201415
# 271902                                         1     201213
# 271903                                         4     201718
# 271904                                         1     201314
#
#         Year_ItemName_ENG Year_ItemNotes_ENG Year_SortOrder
# 0                 2005-06                                67
# 1                 2001-02                                63
# 2                 2005-06                                67
# 3                 2005-06                                67
# 4                 2007-08                                69
# 5                 2007-08                                69
# 6                 2007-08                                69
# 7                 2007-08                                69
# 8                 2006-07                                68
# 9                 2006-07                                68
# 10                2006-07                                68
# 11                2006-07                                68
# 12                2005-06                                67
# 13                2005-06                                67
# 14                2005-06                                67
# 15                2005-06                                67
# 16                2007-08                                69
# 17                2007-08                                69
# 18                2007-08                                69
# 19                2007-08                                69
# 20                2005-06                                67
# 21                2007-08                                69
# 22                2007-08                                69
# 23                2007-08                                69
# 24                2007-08                                69
# 25                2007-08                                69
# 26                2007-08                                69
# 27                2007-08                                69
# 28                2007-08                                69
# 29                2014-15                                76
# ...                   ...                ...            ...
# 271875            2017-18                                79
# 271876            2011-12                                73
# 271877            2011-12                                73
# 271878            2011-12                                73
# 271879            2011-12                                73
# 271880            2011-12                                73
# 271881            2009-10                                71
# 271882            2009-10                                71
# 271883            2009-10                                71
# 271884            2016-17                                78
# 271885            2001-02                                63
# 271886            2015-16                                77
# 271887            2014-15                                76
# 271888            2014-15                                76
# 271889            2011-12                                73
# 271890            2011-12                                73
# 271891            2011-12                                73
# 271892            2011-12                                73
# 271893            2013-14                                75
# 271894            2013-14                                75
# 271895            2015-16                                77
# 271896            2015-16                                77
# 271897            2016-17                                78
# 271898            2016-17                                78
# 271899            2003-04                                65
# 271900            2015-16                                77
# 271901            2014-15                                76
# 271902            2012-13                                74
# 271903            2017-18                                79
# 271904            2013-14                                75
#
# [271905 rows x 31 columns]

# %%
table.columns
# Out:
# Index(['Area_AltCode1', 'Area_Code', 'Area_Hierarchy', 'Area_ItemName_ENG',
#        'Area_SortOrder', 'Availability_Code', 'Availability_Hierarchy',
#        'Availability_ItemName_ENG', 'Availability_SortOrder', 'Data',
#        'Duration_Code', 'Duration_Hierarchy', 'Duration_ItemName_ENG',
#        'Duration_ItemNotes_ENG', 'Duration_SortOrder', 'PartitionKey',
#        'Provider_Code', 'Provider_Hierarchy', 'Provider_ItemName_ENG',
#        'Provider_ItemNotes_ENG', 'Provider_SortOrder', 'RowKey',
#        'Vacancy_Code', 'Vacancy_Hierarchy', 'Vacancy_ItemName_ENG',
#        'Vacancy_ItemNotes_ENG', 'Vacancy_SortOrder', 'Year_Code',
#        'Year_ItemName_ENG', 'Year_ItemNotes_ENG', 'Year_SortOrder'],
#       dtype='object')

# %% [markdown]
# StatsWales uses labels (ItemName_ENG) and notations (Code) for concepts, as well as alternative notations (AltCodeN) where appropriate. We'll use these codes for concepts specific to StatsWales, and for others we'll try to harmonise via labels.

# %%
cols = {
    'Area_AltCode1': 'Geography',
    'Availability_Code': 'Availability',
    'Data': 'Value',
    'Duration_Code': 'Vacancy length', # existing component
    'Provider_Code': 'Provider',
    'Vacancy_Code': 'Vacancy type',
    'Year_Code': 'Period'
}
to_remove = set(table.columns) - set(cols.keys())
table.rename(columns=cols, inplace=True)
table.drop(columns=to_remove, inplace=True)
table
# Out:
#         Geography  Availability  Value  Vacancy length  Provider  \
# 0       W06000016             1     -1               1       540
# 1       W06000021             1     -2               1       548
# 2       W06000022             2     -8               1       550
# 3       W06000004             1   -999               2       518
# 4       W06000013             2   -999               2       536
# 5       W06000013             1   -999               2       536
# 6       W06000013             2   -999               1       536
# 7       W06000013             1   -999               1       536
# 8       W06000013             1   -999               1       536
# 9       W06000013             2   -999               1       536
# 10      W06000013             2   -999               2       536
# 11      W06000013             1   -999               2       536
# 12      W06000013             2   -999               2       536
# 13      W06000013             1   -999               1       536
# 14      W06000013             2   -999               1       536
# 15      W06000013             1   -999               2       536
# 16      W06000016             2   -999               2       540
# 17      W06000016             1   -999               2       540
# 18      W06000016             2   -999               1       540
# 19      W06000016             1   -999               1       540
# 20      W06000019             1   -999               2       545
# 21      W06000020             1   -999               2       546
# 22      W06000020             2   -999               2       546
# 23      W06000020             1   -999               1       546
# 24      W06000020             2   -999               1       546
# 25      W06000021             2   -999               2       548
# 26      W06000021             2   -999               1       548
# 27      W06000021             1   -999               1       548
# 28      W06000021             1   -999               2       548
# 29      W06000001             3      0               1       512
# ...           ...           ...    ...             ...       ...
# 271875  W06000013             3     99               3       600
# 271876  W06000019             3     99               2       600
# 271877  W06000019             3     99               3       600
# 271878  W06000019             3     99               2       600
# 271879  W06000016             2     99               2       600
# 271880  W06000016             2     99               2       600
# 271881  W06000012             1     99               1       600
# 271882  W06000014             1     99               3       600
# 271883  W06000012             1     99               3       600
# 271884  W92000004             3     99               3       940
# 271885  W06000011             3     99               3       940
# 271886  W92000004             3     99               1       940
# 271887  W92000004             3     99               3       995
# 271888  W92000004             3     99               3       995
# 271889  W92000004             3     99               1      1021
# 271890  W92000004             3     99               1      1021
# 271891  W06000016             3     99               1      1021
# 271892  W06000016             3     99               1      1021
# 271893  W92000004             1     99               3      1027
# 271894  W06000022             1     99               3      1027
# 271895  W92000004             3     99               3      1027
# 271896  W06000022             3     99               3      1027
# 271897  W92000004             2     99               2      1032
# 271898  W06000012             2     99               2      1032
# 271899  W06000016             3    991               3       600
# 271900  W92000004             1    992               3       592
# 271901  W92000004             2    994               1       600
# 271902  W92000004             2    994               1       600
# 271903  W92000004             2    996               1       600
# 271904  W92000004             2    998               3       592
#
#         Vacancy type  Period
# 0                6.0  200506
# 1                6.0  200102
# 2                6.0  200506
# 3                6.0  200506
# 4                6.0  200708
# 5                6.0  200708
# 6                6.0  200708
# 7                6.0  200708
# 8                6.0  200607
# 9                6.0  200607
# 10               6.0  200607
# 11               6.0  200607
# 12               6.0  200506
# 13               6.0  200506
# 14               6.0  200506
# 15               6.0  200506
# 16               6.0  200708
# 17               6.0  200708
# 18               6.0  200708
# 19               6.0  200708
# 20               6.0  200506
# 21               6.0  200708
# 22               6.0  200708
# 23               6.0  200708
# 24               6.0  200708
# 25               6.0  200708
# 26               6.0  200708
# 27               6.0  200708
# 28               6.0  200708
# 29               2.2  201415
# ...              ...     ...
# 271875           5.0  201718
# 271876           5.0  201112
# 271877           2.1  201112
# 271878           6.0  201112
# 271879           2.0  201112
# 271880           2.1  201112
# 271881           5.0  200910
# 271882           6.0  200910
# 271883           1.0  200910
# 271884           6.0  201617
# 271885           6.0  200102
# 271886           6.0  201516
# 271887           6.0  201415
# 271888           5.0  201415
# 271889           5.0  201112
# 271890           6.0  201112
# 271891           6.0  201112
# 271892           5.0  201112
# 271893           6.0  201314
# 271894           6.0  201314
# 271895           1.0  201516
# 271896           1.0  201516
# 271897           5.0  201617
# 271898           5.0  201617
# 271899           6.0  200304
# 271900           1.0  201516
# 271901           1.0  201415
# 271902           6.0  201213
# 271903           1.0  201718
# 271904           6.0  201314
#
# [271905 rows x 7 columns]

# %% [markdown]
# The OData API offers an "Items" endpoint that enumerates the values of the various dimensions and provides information about the hierarchy.

# %%
try:
    items_dist = scraper.distribution(title='Items')
except:
    from gssutils.metadata import Distribution
    dist = Distribution(scraper)
    dist.title = 'Items'
    dist.downloadURL = 'http://open.statswales.gov.wales/en-gb/discover/datasetdimensionitems?$filter=Dataset%20eq%20%27hous1401%27'
    dist.mediaType = 'application/json'
    scraper.distributions.append(dist)
    items_dist = scraper.distribution(title='Items')
items = items_dist.as_pandas()
items
# Out:
#     AltCode1 AltCode2 AltCode3      Code   Dataset  \
# 0                                    2.1  hous1401
# 1                                    2.2  hous1401
# 2                                  983.0  hous1401
# 3                                  980.0  hous1401
# 4                                 1024.0  hous1401
# 5                                  930.0  hous1401
# 6                                 1021.0  hous1401
# 7                                  925.0  hous1401
# 8                                 1020.0  hous1401
# 9                                 1032.0  hous1401
# 10                                1023.0  hous1401
# 11                                 988.0  hous1401
# 12                                1028.0  hous1401
# 13                                1022.0  hous1401
# 14                                1029.0  hous1401
# 15                                1031.0  hous1401
# 16                                1012.0  hous1401
# 17                                 971.0  hous1401
# 18                                1027.0  hous1401
# 19                                1030.0  hous1401
# 20                                1026.0  hous1401
# 21                                 945.0  hous1401
# 22                                1025.0  hous1401
# 23                                 992.0  hous1401
# 24                                 928.0  hous1401
# 25                                 937.0  hous1401
# 26                                 927.0  hous1401
# 27                                1007.0  hous1401
# 28                                1034.0  hous1401
# 29                                 946.0  hous1401
# ..       ...      ...      ...       ...       ...
# 168                                  2.0  hous1401
# 169                                  3.0  hous1401
# 170                                  4.0  hous1401
# 171                                  5.0  hous1401
# 172                                  6.0  hous1401
# 173                                  1.0  hous1401
# 174                                  2.0  hous1401
# 175                                  3.0  hous1401
# 176                             199697.0  hous1401
# 177                             199798.0  hous1401
# 178                             199899.0  hous1401
# 179                             199900.0  hous1401
# 180                             200001.0  hous1401
# 181                             200102.0  hous1401
# 182                             200203.0  hous1401
# 183                             200304.0  hous1401
# 184                             200405.0  hous1401
# 185                             200506.0  hous1401
# 186                             200607.0  hous1401
# 187                             200708.0  hous1401
# 188                             200809.0  hous1401
# 189                             200910.0  hous1401
# 190                             201011.0  hous1401
# 191                             201112.0  hous1401
# 192                             201213.0  hous1401
# 193                             201314.0  hous1401
# 194                             201415.0  hous1401
# 195                             201516.0  hous1401
# 196                             201617.0  hous1401
# 197                             201718.0  hous1401
#
#                                        Description_ENG DimensionName_ENG  \
# 0      Self-contained sheltered (2011-12 onwards only)           Vacancy
# 1    Self-contained other supported (2011-12 onward...           Vacancy
# 2                                     Abbeyfield Wales          Provider
# 3            Slocombe Cottages for the Aged and Infirm          Provider
# 4                                Coastal Housing Group          Provider
# 5                        Cynon Taf Housing Association          Provider
# 6                                            Trivallis          Provider
# 7                                         Grwp Cynefin          Provider
# 8                                          Melin Homes          Provider
# 9                                            NPT Homes          Provider
# 10                               Monmouthshire Housing          Provider
# 11                         Swansea Housing Association          Provider
# 12                               Merthyr Valleys Homes          Provider
# 13                   Cynon-Taf Community Housing Group          Provider
# 14                                      Tai Ceredigion          Provider
# 15                         Tai Calon Community Housing          Provider
# 16                            Valleys to Coast Housing          Provider
# 17         Pontypridd and District Housing Association          Provider
# 18                                  Newport City Homes          Provider
# 19                          Cartrefi Cymunedol Gwynedd          Provider
# 20                                      Cartrefi Conwy          Provider
# 21                                     Fairlake Living          Provider
# 22                         Bron Afon Community Housing          Provider
# 23                             Gofal a Chymorth Gwalia          Provider
# 24                                Cymdeithas Tai Eryri          Provider
# 25                                          Linc Cymru          Provider
# 26                       Dewi Sant Housing Association          Provider
# 27                                              Derwen          Provider
# 28                                         Pobl Living          Provider
# 29                  Gwerin (Cymru) Housing Association          Provider
# ..                                                 ...               ...
# 168  Self-contained sheltered and other supported (...           Vacancy
# 169                          Self-contained extra care           Vacancy
# 170                                 Non self-contained           Vacancy
# 171                                 All self-contained           Vacancy
# 172                                              Total           Vacancy
# 173                      Vacant for less than 6 months          Duration
# 174                        Vacant for 6 months or more          Duration
# 175                                              Total          Duration
# 176                                            1996-97              Year
# 177                                            1997-98              Year
# 178                                            1998-99              Year
# 179                                            1999-00              Year
# 180                                            2000-01              Year
# 181                                            2001-02              Year
# 182                                            2002-03              Year
# 183                                            2003-04              Year
# 184                                            2004-05              Year
# 185                                            2005-06              Year
# 186                                            2006-07              Year
# 187                                            2007-08              Year
# 188                                            2008-09              Year
# 189                                            2009-10              Year
# 190                                            2010-11              Year
# 191                                            2011-12              Year
# 192                                            2012-13              Year
# 193                                            2013-14              Year
# 194                                            2014-15              Year
# 195                                            2015-16              Year
# 196                                            2016-17              Year
# 197                                            2017-18              Year
#
#     Hierarchy  Notes_ENG SemanticKey  SortOrder
# 0           5        NaN                    NaN
# 1           5        NaN                    NaN
# 2        3000        NaN                    NaN
# 3        3001        NaN                    NaN
# 4         592        NaN                    NaN
# 5         592        NaN                    NaN
# 6         592        NaN                    NaN
# 7         592        NaN                    NaN
# 8         592        NaN                    NaN
# 9         592        NaN                    NaN
# 10        592        NaN                    NaN
# 11        592        NaN                    NaN
# 12        592        NaN                    NaN
# 13        592        NaN                    NaN
# 14        592        NaN                    NaN
# 15        592        NaN                    NaN
# 16        592        NaN                    NaN
# 17        592        NaN                    NaN
# 18        592        NaN                    NaN
# 19        592        NaN                    NaN
# 20        592        NaN                    NaN
# 21        592        NaN                    NaN
# 22        592        NaN                    NaN
# 23        592        NaN                    NaN
# 24        592        NaN                    NaN
# 25        592        NaN                    NaN
# 26        592        NaN                    NaN
# 27        592        NaN                    NaN
# 28        592        NaN                    NaN
# 29        592        NaN                    NaN
# ..        ...        ...         ...        ...
# 168         5        NaN                    NaN
# 169         5        NaN                    NaN
# 170         6        NaN                    NaN
# 171         6        NaN                    NaN
# 172                  NaN                    NaN
# 173         3        NaN                    NaN
# 174         3        NaN                    NaN
# 175                  NaN                    NaN
# 176                  NaN                    NaN
# 177                  NaN                    NaN
# 178                  NaN                    NaN
# 179                  NaN                    NaN
# 180                  NaN                    NaN
# 181                  NaN                    NaN
# 182                  NaN                    NaN
# 183                  NaN                    NaN
# 184                  NaN                    NaN
# 185                  NaN                    NaN
# 186                  NaN                    NaN
# 187                  NaN                    NaN
# 188                  NaN                    NaN
# 189                  NaN                    NaN
# 190                  NaN                    NaN
# 191                  NaN                    NaN
# 192                  NaN                    NaN
# 193                  NaN                    NaN
# 194                  NaN                    NaN
# 195                  NaN                    NaN
# 196                  NaN                    NaN
# 197                  NaN                    NaN
#
# [198 rows x 11 columns]

# %%
from collections import OrderedDict
item_cols = OrderedDict([
    ('Description_ENG', 'Label'),
    ('Code', 'Notation'),
    ('Hierarchy', 'Parent Notation'),
    ('SortOrder', 'Sort Priority')
])

def extract_codelist(dimension):
    codelist = items[items['DimensionName_ENG'] == dimension].rename(
        columns=item_cols).drop(
        columns=set(items.columns) - set(item_cols.keys()))[list(item_cols.values())]
    codelist['Notation'] = codelist['Notation'].map(
        lambda x: str(int(x)) if str(x).endswith(".0") else str(x)
    )
    return codelist

codelists = {
    'vacancies': extract_codelist('Vacancy'),
    'providers': extract_codelist('Provider'),
    'availability': extract_codelist('Availability'),
    'durations': extract_codelist('Duration')
}

out = Path('out')
out.mkdir(exist_ok=True, parents=True)

for name, codelist in codelists.items():
    codelist.to_csv(out / f'{name}.csv', index = False)
    display(name)
    display(codelist)
# Out:
# 'vacancies'
#                                                  Label Notation  \
# 0      Self-contained sheltered (2011-12 onwards only)      2.1
# 1    Self-contained other supported (2011-12 onward...      2.2
# 167                       Self-contained general needs        1
# 168  Self-contained sheltered and other supported (...        2
# 169                          Self-contained extra care        3
# 170                                 Non self-contained        4
# 171                                 All self-contained        5
# 172                                              Total        6
#
#     Parent Notation  Sort Priority
# 0                 5            NaN
# 1                 5            NaN
# 167               5            NaN
# 168               5            NaN
# 169               5            NaN
# 170               6            NaN
# 171               6            NaN
# 172                            NaN
# 'providers'
#                                                  Label Notation  \
# 2                                     Abbeyfield Wales      983
# 3            Slocombe Cottages for the Aged and Infirm      980
# 4                                Coastal Housing Group     1024
# 5                        Cynon Taf Housing Association      930
# 6                                            Trivallis     1021
# 7                                         Grwp Cynefin      925
# 8                                          Melin Homes     1020
# 9                                            NPT Homes     1032
# 10                               Monmouthshire Housing     1023
# 11                         Swansea Housing Association      988
# 12                               Merthyr Valleys Homes     1028
# 13                   Cynon-Taf Community Housing Group     1022
# 14                                      Tai Ceredigion     1029
# 15                         Tai Calon Community Housing     1031
# 16                            Valleys to Coast Housing     1012
# 17         Pontypridd and District Housing Association      971
# 18                                  Newport City Homes     1027
# 19                          Cartrefi Cymunedol Gwynedd     1030
# 20                                      Cartrefi Conwy     1026
# 21                                     Fairlake Living      945
# 22                         Bron Afon Community Housing     1025
# 23                             Gofal a Chymorth Gwalia      992
# 24                                Cymdeithas Tai Eryri      928
# 25                                          Linc Cymru      937
# 26                       Dewi Sant Housing Association      927
# 27                                              Derwen     1007
# 28                                         Pobl Living     1034
# 29                  Gwerin (Cymru) Housing Association      946
# 30                                             Torfaen      546
# 31                                       Blaenau Gwent      545
# ..                                                 ...      ...
# 137                   Cymdeithas Tai Cymdogaeth Gwalia      926
# 138                                        Hafan Cymru      929
# 139                 Family Housing Association (Wales)      934
# 140                                   Abbeyfield Flint      935
# 141                   First Choice Housing Association      936
# 142  Gwalia Rest Bay (Co-Ownership Equity Sharing) ...      943
# 143                       Gwynfyd Housing Co-Operative      947
# 144                           Henry Burtons Almshouses      951
# 145                      Letitia Cornwallis Almshouses      952
# 146                               Abbeyfield Llandeilo      953
# 147                                Abbeyfield Llanrwst      957
# 148                               Llewellyn Almshouses      958
# 149                 Merthyr Tydfil Housing Association      960
# 150                      Mid Wales Housing Association      961
# 151                    North Wales Housing Association      967
# 152                  Pembrokeshire Housing Association      969
# 153                             Polish Housing Society      970
# 154                          Rachel Herbert Almshouses      974
# 155  Roger Williams and Queen Victoria Memorial Alm...      977
# 156                                   Ruabon Almshouse      978
# 157       Soroptimist Housing Association (Carmarthen)      981
# 158            St David's Diocesan Housing Association      986
# 159                           Taff Housing Association      989
# 160                                  Tai Charles Jones      990
# 161                     The Goodman and Ruthin Charity      991
# 162                   United Welsh Housing Association      994
# 163                             Wales and West Housing      995
# 164                                 Abbeyfield Wrexham      996
# 165                                   Abbeyfield Total     3000
# 166                                    Almshouse total     3001
#
#     Parent Notation  Sort Priority
# 2              3000            NaN
# 3              3001            NaN
# 4               592            NaN
# 5               592            NaN
# 6               592            NaN
# 7               592            NaN
# 8               592            NaN
# 9               592            NaN
# 10              592            NaN
# 11              592            NaN
# 12              592            NaN
# 13              592            NaN
# 14              592            NaN
# 15              592            NaN
# 16              592            NaN
# 17              592            NaN
# 18              592            NaN
# 19              592            NaN
# 20              592            NaN
# 21              592            NaN
# 22              592            NaN
# 23              592            NaN
# 24              592            NaN
# 25              592            NaN
# 26              592            NaN
# 27              592            NaN
# 28              592            NaN
# 29              592            NaN
# 30              596            NaN
# 31              596            NaN
# ..              ...            ...
# 137             592            NaN
# 138             592            NaN
# 139             592            NaN
# 140            3000            NaN
# 141             592            NaN
# 142             592            NaN
# 143             592            NaN
# 144            3001            NaN
# 145            3001            NaN
# 146            3000            NaN
# 147            3000            NaN
# 148            3001            NaN
# 149             592            NaN
# 150             592            NaN
# 151             592            NaN
# 152             592            NaN
# 153             592            NaN
# 154            3001            NaN
# 155            3001            NaN
# 156            3001            NaN
# 157             592            NaN
# 158             592            NaN
# 159             592            NaN
# 160            3001            NaN
# 161            3001            NaN
# 162             592            NaN
# 163             592            NaN
# 164            3000            NaN
# 165             592            NaN
# 166             592            NaN
#
# [139 rows x 4 columns]
# 'availability'
#                         Label Notation Parent Notation  Sort Priority
# 87      Available for letting        1               3            NaN
# 88  Not available for letting        2               3            NaN
# 89                      Total        3                            NaN
# 'durations'
#                              Label Notation Parent Notation  Sort Priority
# 173  Vacant for less than 6 months        1               3            NaN
# 174    Vacant for 6 months or more        2               3            NaN
# 175                          Total        3                            NaN

# %%
table['Period'] = table['Period'].map(lambda x: f'gregorian-interval/{str(x)[:4]}-03-31T00:00:00/P1Y')
table['Vacancy type'] = table['Vacancy type'].map(lambda x: str(int(x)) if str(x).endswith(".0") else str(x))
table['Vacancy length'] = table['Vacancy length'].map({
    1: 'less-than-6-months',
    2: '6-months-or-more',
    3: 'total'}.get)
table['Measure Type'] = 'Count'
table['Unit'] = 'vacancies'

# %%
table.drop_duplicates().to_csv(out / 'observations.csv', index = False)

# %%
schema = CSVWSchema('https://ons-opendata.github.io/ref_housing/')
schema.create(out / 'observations.csv', out / 'observations.csv-schema.json')

# %%
from datetime import datetime
scraper.dataset.family = 'housing'
scraper.dataset.theme = THEME['housing-planning-local-services']
scraper.dataset.modified = datetime.now()
scraper.dataset.creator = scraper.dataset.publisher
with open(out / 'dataset.trig', 'wb') as metadata:
    metadata.write(scraper.generate_trig())

# %%
table
# Out:
#         Geography  Availability  Value      Vacancy length  Provider  \
# 0       W06000016             1     -1  less-than-6-months       540
# 1       W06000021             1     -2  less-than-6-months       548
# 2       W06000022             2     -8  less-than-6-months       550
# 3       W06000004             1   -999    6-months-or-more       518
# 4       W06000013             2   -999    6-months-or-more       536
# 5       W06000013             1   -999    6-months-or-more       536
# 6       W06000013             2   -999  less-than-6-months       536
# 7       W06000013             1   -999  less-than-6-months       536
# 8       W06000013             1   -999  less-than-6-months       536
# 9       W06000013             2   -999  less-than-6-months       536
# 10      W06000013             2   -999    6-months-or-more       536
# 11      W06000013             1   -999    6-months-or-more       536
# 12      W06000013             2   -999    6-months-or-more       536
# 13      W06000013             1   -999  less-than-6-months       536
# 14      W06000013             2   -999  less-than-6-months       536
# 15      W06000013             1   -999    6-months-or-more       536
# 16      W06000016             2   -999    6-months-or-more       540
# 17      W06000016             1   -999    6-months-or-more       540
# 18      W06000016             2   -999  less-than-6-months       540
# 19      W06000016             1   -999  less-than-6-months       540
# 20      W06000019             1   -999    6-months-or-more       545
# 21      W06000020             1   -999    6-months-or-more       546
# 22      W06000020             2   -999    6-months-or-more       546
# 23      W06000020             1   -999  less-than-6-months       546
# 24      W06000020             2   -999  less-than-6-months       546
# 25      W06000021             2   -999    6-months-or-more       548
# 26      W06000021             2   -999  less-than-6-months       548
# 27      W06000021             1   -999  less-than-6-months       548
# 28      W06000021             1   -999    6-months-or-more       548
# 29      W06000001             3      0  less-than-6-months       512
# ...           ...           ...    ...                 ...       ...
# 271875  W06000013             3     99               total       600
# 271876  W06000019             3     99    6-months-or-more       600
# 271877  W06000019             3     99               total       600
# 271878  W06000019             3     99    6-months-or-more       600
# 271879  W06000016             2     99    6-months-or-more       600
# 271880  W06000016             2     99    6-months-or-more       600
# 271881  W06000012             1     99  less-than-6-months       600
# 271882  W06000014             1     99               total       600
# 271883  W06000012             1     99               total       600
# 271884  W92000004             3     99               total       940
# 271885  W06000011             3     99               total       940
# 271886  W92000004             3     99  less-than-6-months       940
# 271887  W92000004             3     99               total       995
# 271888  W92000004             3     99               total       995
# 271889  W92000004             3     99  less-than-6-months      1021
# 271890  W92000004             3     99  less-than-6-months      1021
# 271891  W06000016             3     99  less-than-6-months      1021
# 271892  W06000016             3     99  less-than-6-months      1021
# 271893  W92000004             1     99               total      1027
# 271894  W06000022             1     99               total      1027
# 271895  W92000004             3     99               total      1027
# 271896  W06000022             3     99               total      1027
# 271897  W92000004             2     99    6-months-or-more      1032
# 271898  W06000012             2     99    6-months-or-more      1032
# 271899  W06000016             3    991               total       600
# 271900  W92000004             1    992               total       592
# 271901  W92000004             2    994  less-than-6-months       600
# 271902  W92000004             2    994  less-than-6-months       600
# 271903  W92000004             2    996  less-than-6-months       600
# 271904  W92000004             2    998               total       592
#
#        Vacancy type                                      Period Measure Type  \
# 0                 6  gregorian-interval/2005-03-31T00:00:00/P1Y        Count
# 1                 6  gregorian-interval/2001-03-31T00:00:00/P1Y        Count
# 2                 6  gregorian-interval/2005-03-31T00:00:00/P1Y        Count
# 3                 6  gregorian-interval/2005-03-31T00:00:00/P1Y        Count
# 4                 6  gregorian-interval/2007-03-31T00:00:00/P1Y        Count
# 5                 6  gregorian-interval/2007-03-31T00:00:00/P1Y        Count
# 6                 6  gregorian-interval/2007-03-31T00:00:00/P1Y        Count
# 7                 6  gregorian-interval/2007-03-31T00:00:00/P1Y        Count
# 8                 6  gregorian-interval/2006-03-31T00:00:00/P1Y        Count
# 9                 6  gregorian-interval/2006-03-31T00:00:00/P1Y        Count
# 10                6  gregorian-interval/2006-03-31T00:00:00/P1Y        Count
# 11                6  gregorian-interval/2006-03-31T00:00:00/P1Y        Count
# 12                6  gregorian-interval/2005-03-31T00:00:00/P1Y        Count
# 13                6  gregorian-interval/2005-03-31T00:00:00/P1Y        Count
# 14                6  gregorian-interval/2005-03-31T00:00:00/P1Y        Count
# 15                6  gregorian-interval/2005-03-31T00:00:00/P1Y        Count
# 16                6  gregorian-interval/2007-03-31T00:00:00/P1Y        Count
# 17                6  gregorian-interval/2007-03-31T00:00:00/P1Y        Count
# 18                6  gregorian-interval/2007-03-31T00:00:00/P1Y        Count
# 19                6  gregorian-interval/2007-03-31T00:00:00/P1Y        Count
# 20                6  gregorian-interval/2005-03-31T00:00:00/P1Y        Count
# 21                6  gregorian-interval/2007-03-31T00:00:00/P1Y        Count
# 22                6  gregorian-interval/2007-03-31T00:00:00/P1Y        Count
# 23                6  gregorian-interval/2007-03-31T00:00:00/P1Y        Count
# 24                6  gregorian-interval/2007-03-31T00:00:00/P1Y        Count
# 25                6  gregorian-interval/2007-03-31T00:00:00/P1Y        Count
# 26                6  gregorian-interval/2007-03-31T00:00:00/P1Y        Count
# 27                6  gregorian-interval/2007-03-31T00:00:00/P1Y        Count
# 28                6  gregorian-interval/2007-03-31T00:00:00/P1Y        Count
# 29              2.2  gregorian-interval/2014-03-31T00:00:00/P1Y        Count
# ...             ...                                         ...          ...
# 271875            5  gregorian-interval/2017-03-31T00:00:00/P1Y        Count
# 271876            5  gregorian-interval/2011-03-31T00:00:00/P1Y        Count
# 271877          2.1  gregorian-interval/2011-03-31T00:00:00/P1Y        Count
# 271878            6  gregorian-interval/2011-03-31T00:00:00/P1Y        Count
# 271879            2  gregorian-interval/2011-03-31T00:00:00/P1Y        Count
# 271880          2.1  gregorian-interval/2011-03-31T00:00:00/P1Y        Count
# 271881            5  gregorian-interval/2009-03-31T00:00:00/P1Y        Count
# 271882            6  gregorian-interval/2009-03-31T00:00:00/P1Y        Count
# 271883            1  gregorian-interval/2009-03-31T00:00:00/P1Y        Count
# 271884            6  gregorian-interval/2016-03-31T00:00:00/P1Y        Count
# 271885            6  gregorian-interval/2001-03-31T00:00:00/P1Y        Count
# 271886            6  gregorian-interval/2015-03-31T00:00:00/P1Y        Count
# 271887            6  gregorian-interval/2014-03-31T00:00:00/P1Y        Count
# 271888            5  gregorian-interval/2014-03-31T00:00:00/P1Y        Count
# 271889            5  gregorian-interval/2011-03-31T00:00:00/P1Y        Count
# 271890            6  gregorian-interval/2011-03-31T00:00:00/P1Y        Count
# 271891            6  gregorian-interval/2011-03-31T00:00:00/P1Y        Count
# 271892            5  gregorian-interval/2011-03-31T00:00:00/P1Y        Count
# 271893            6  gregorian-interval/2013-03-31T00:00:00/P1Y        Count
# 271894            6  gregorian-interval/2013-03-31T00:00:00/P1Y        Count
# 271895            1  gregorian-interval/2015-03-31T00:00:00/P1Y        Count
# 271896            1  gregorian-interval/2015-03-31T00:00:00/P1Y        Count
# 271897            5  gregorian-interval/2016-03-31T00:00:00/P1Y        Count
# 271898            5  gregorian-interval/2016-03-31T00:00:00/P1Y        Count
# 271899            6  gregorian-interval/2003-03-31T00:00:00/P1Y        Count
# 271900            1  gregorian-interval/2015-03-31T00:00:00/P1Y        Count
# 271901            1  gregorian-interval/2014-03-31T00:00:00/P1Y        Count
# 271902            6  gregorian-interval/2012-03-31T00:00:00/P1Y        Count
# 271903            1  gregorian-interval/2017-03-31T00:00:00/P1Y        Count
# 271904            6  gregorian-interval/2013-03-31T00:00:00/P1Y        Count
#
#              Unit
# 0       vacancies
# 1       vacancies
# 2       vacancies
# 3       vacancies
# 4       vacancies
# 5       vacancies
# 6       vacancies
# 7       vacancies
# 8       vacancies
# 9       vacancies
# 10      vacancies
# 11      vacancies
# 12      vacancies
# 13      vacancies
# 14      vacancies
# 15      vacancies
# 16      vacancies
# 17      vacancies
# 18      vacancies
# 19      vacancies
# 20      vacancies
# 21      vacancies
# 22      vacancies
# 23      vacancies
# 24      vacancies
# 25      vacancies
# 26      vacancies
# 27      vacancies
# 28      vacancies
# 29      vacancies
# ...           ...
# 271875  vacancies
# 271876  vacancies
# 271877  vacancies
# 271878  vacancies
# 271879  vacancies
# 271880  vacancies
# 271881  vacancies
# 271882  vacancies
# 271883  vacancies
# 271884  vacancies
# 271885  vacancies
# 271886  vacancies
# 271887  vacancies
# 271888  vacancies
# 271889  vacancies
# 271890  vacancies
# 271891  vacancies
# 271892  vacancies
# 271893  vacancies
# 271894  vacancies
# 271895  vacancies
# 271896  vacancies
# 271897  vacancies
# 271898  vacancies
# 271899  vacancies
# 271900  vacancies
# 271901  vacancies
# 271902  vacancies
# 271903  vacancies
# 271904  vacancies
#
# [271905 rows x 9 columns]
